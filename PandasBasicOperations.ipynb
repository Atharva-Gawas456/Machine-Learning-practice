# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'age': [18, 19, 20],
    'name': ["Atharva", "Ajay", "Sameer"],
    'work': ["Computers", "Machines", "Electrical"],
})

# %% [markdown]
# ### Basic Start of Pandas

# %%
df.head()
# Out:
#    age     name        work
# 0   18  Atharva   Computers
# 1   19     Ajay    Machines
# 2   20   Sameer  Electrical

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['age', 'name', 'work'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# age      int64
# name    object
# work    object
# dtype: object

# %%
df.values
# Out:
# array([[18, 'Atharva', 'Computers'],
#        [19, 'Ajay', 'Machines'],
#        [20, 'Sameer', 'Electrical']], dtype=object)

# %%
df.to_csv("practice_output.csv", index=False)

# %% [markdown]
# ### Basic ML operations of pandas

# %%
df.head()
# Out:
#    age     name        work
# 0   18  Atharva   Computers
# 1   19     Ajay    Machines
# 2   20   Sameer  Electrical
