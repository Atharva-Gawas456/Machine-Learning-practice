# %%
import pandas as pd

# %% [markdown]
# # 5.1 Introduction to pandas Data Structure

# %% [markdown]
# ## Series

# %%
obj = pd.Series([4, 5, 7, 8])
obj
# Out:
# 0    4
# 1    5
# 2    7
# 3    8
# dtype: int64

# %%
obj.array
# Out:
# <PandasArray>
# [4, 5, 7, 8]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([1, 2, 3, 4], index = ['D', 'A', 'C', 'B'])

# %%
obj2
# Out:
# D    1
# A    2
# C    3
# B    4
# dtype: int64

# %%
obj2.index
# Out:
# Index(['D', 'A', 'C', 'B'], dtype='object')

# %%
obj2['B']
# Out:
# 4

# %%
obj2['B'] = 0
obj2
# Out:
# D    1
# A    2
# C    3
# B    0
# dtype: int64

# %%
obj2[obj2 > 0]
# Out:
# D    1
# A    2
# C    3
# dtype: int64

# %%
obj2*2
# Out:
# D    2
# A    4
# C    6
# B    0
# dtype: int64

# %%
import numpy as np

# %%
np.exp(obj2)
# Out:
# D     2.718282
# A     7.389056
# C    20.085537
# B     1.000000
# dtype: float64

# %%
"B" in obj2
# Out:
# True

# %%
sdata = {
    "Ohio": 35000,
    "Texas": 71000,
    "Oregon": 16000,
    "Utah": 5000
}

obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name = "population"

obj4.index.name = "state"
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj
# Out:
# Bob      4
# Steve    5
# Jeff     7
# Ryan     8
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
data = {
    "state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
    "year": [2000, 2001, 2002, 2001, 2002, 2003],
    "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

frame = pd.DataFrame(data)

frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns = ['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns = ["year", "state", "pop", "debt"])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2.loc[1]
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
frame2["debt"] = 10
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5    10
# 1  2001    Ohio  1.7    10
# 2  2002    Ohio  3.6    10
# 3  2001  Nevada  2.4    10
# 4  2002  Nevada  2.9    10
# 5  2003  Nevada  3.2    10

# %%
d = 10
for i in range(6):
    frame2["debt"].loc[i] = d
    d += 2

frame2
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_13516\3101432821.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame2["debt"].loc[i] = d
#    year   state  pop  debt
# 0  2000    Ohio  1.5    10
# 1  2001    Ohio  1.7    12
# 2  2002    Ohio  3.6    14
# 3  2001  Nevada  2.4    16
# 4  2002  Nevada  2.9    18
# 5  2003  Nevada  3.2    20

# %%
frame2["eastern"] = frame2["state"] == "Ohio"
frame2
# Out:
#    year   state  pop  debt  eastern
# 0  2000    Ohio  1.5    10     True
# 1  2001    Ohio  1.7    12     True
# 2  2002    Ohio  3.6    14     True
# 3  2001  Nevada  2.4    16    False
# 4  2002  Nevada  2.9    18    False
# 5  2003  Nevada  3.2    20    False
