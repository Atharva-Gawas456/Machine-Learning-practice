# %%
import pandas as pd

# %%
df = pd.read_csv("dirty_dataset.csv")

# %%
df.head()
# Out:
#    id          name     age  gender salary joining_date   department  \
# 0   1      John Doe      28    Male  50000   2021-05-10  Engineering
# 1   2   Jane Smith      NaN  Female  60000   10/06/2020           HR
# 2   3   Bob Johnson  thirty    Male  55000   2019-07-15  Engineering
# 3   4   Alice Brown      25  Female    NaN   2022-01-20    Marketing
# 4   5   Chris Green      40    Male  70000   2020/03/12      Finance
#
#                    email
# 0     john.doe@email.com
# 1    janesmith@email.com
# 2            bob.j@email
# 3  alice.brown@email.com
# 4  chris.green@email.com

# %%
df.tail()
# Out:
#     id           name  age  gender salary joining_date   department  \
# 10  11  Olivia Martin   26  Female  57000          NaN           HR
# 11  12     Noah Clark   33    Male  72000   2019-09-10  Engineering
# 12  13   Sophia Lewis  abc  Female  61000   2021-04-18    Marketing
# 13  14   James Walker   45    Male  80000   2017-06-25      Finance
# 14  15  Isabella Hall   29  Female  59000   2021-07-11           HR
#
#                       email
# 10  olivia.martin@email.com
# 11     noah.clark@email.com
# 12   sophia.lewis@email.com
# 13   james.walker@email.com
# 14      isabella.hall@email

# %%
df.describe()
# Out:
#               id
# count  15.000000
# mean    8.000000
# std     4.472136
# min     1.000000
# 25%     4.500000
# 50%     8.000000
# 75%    11.500000
# max    15.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            11 non-null     int64
#  1   name          11 non-null     object
#  2   age           11 non-null     object
#  3   gender        11 non-null     object
#  4   salary        11 non-null     object
#  5   joining_date  11 non-null     object
#  6   department    11 non-null     object
#  7   email         11 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 792.0+ bytes

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# age             0
# gender          0
# salary          0
# joining_date    0
# department      0
# email           0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    id         name     age gender         salary joining_date   department  \
# 0   1     John Doe      28   Male          50000   2021-05-10  Engineering
# 2   3  Bob Johnson  thirty   Male          55000   2019-07-15  Engineering
# 4   5  Chris Green      40   Male          70000   2020/03/12      Finance
# 5   6     John Doe      28   Male          50000   2021-05-10  Engineering
# 7   8    David Lee      29   Male  not_available   2021-08-25  Engineering
#
#                    email
# 0     john.doe@email.com
# 2            bob.j@email
# 4  chris.green@email.com
# 5     john.doe@email.com
# 7    david.lee@email.com
