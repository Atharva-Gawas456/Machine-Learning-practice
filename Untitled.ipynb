# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import Lasso
from sklearn.datasets import make_regression

x, y = make_regression(n_samples = 100, n_features = 10, noise = 20, random_state = 42)
lasso = Lasso(alpha = 0.5)
lasso.fit(x, y)

print(lasso.coef_)
# Out:
# [19.57458693 56.06002242  1.8116845  61.96242779 92.23426918 69.04419062
#  83.29205718  6.78354841  3.89813832 69.95335746]

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 0.5)
ridge.fit(x, y)

print(ridge.coef_)
# Out:
# [20.12588263 56.21829199  2.56407213 62.00728708 92.40021568 69.08518977
#  83.52650391  7.45130631  4.32629599 70.12849776]
