# %% [markdown]
# ### Introduction

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %% [markdown]
# ### Data Types

# %%
a = 2
b = 8.9
print(a + b)
# Out:
# 10.9

# %%
arr = [1, 2, 3, 4, 5]
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(int(b))
# Out:
# 8

# %%
print(float(a))
# Out:
# 2.0

# %%
print(int(b) == 8)
# Out:
# True

# %%
print(int(1.0))
# Out:
# 1

# %%
a = bool(1)
print(a)
# Out:
# True

# %% [markdown]
# ### Expressions and Variables

# %%
print(25/6)
# Out:
# 4.166666666666667

# %%
print(56//6)
# Out:
# 9

# %%
total_min = 67+56+63
hour = total_min//60
minutes = total_min%60

print(hour, minutes)
# Out:
# 3 6

# %%
type(12.0)
# Out:
# float

# %% [markdown]
# ### String Operations

# %%
"0123456".find('1')
# Out:
# 1
